# %%
import pandas as pd 
import numpy as np
import math

# %%
df=pd.read_csv("~/Downloads/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Understanding the data

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.isna().sum()
# checking the number of missed values
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.drop(["Id"], axis=1, inplace=True)
# droping the Id column as it has no influence on the model

# %%
mean=df.mean()
df.fillna(mean,inplace=True) 
# replacing nan values with mean values in the numerical columns

# %% [markdown]
# # checking for outliers and replacing them with mean value of the features

# %%
numerical_columns = [column for column in df.columns if df[column].dtype==int and len(df[column].unique()<11)]
numerical_columns=numerical_columns[:-1].copy()

# %%
def outlier_detection(column, df):
    outlier=[]
    for x in  df[column]:
        z=np.divide(x-np.mean(df[column]),np.std(df[column]))
        if z > 3:
            outlier.append(x)
            df[column].replace(x,math.ceil(np.mean(df[column])),inplace=True)
#     print(column, outlier)     
    

for column in numerical_columns:
    outlier_detection(column, df)

# %%
# df["KitchenAbvGr"].unique()

# %%
df.isna().sum() 
# confirming all the nunmerical nan values are gone
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 80, dtype: int64

# %% [markdown]
# # converting categorical features to dummy variables

# %%
categorical_columns = [column for column in df.columns if df[column].dtype=="object"]
# categorical_columns

# %%
df1=pd.get_dummies(data=df,columns=categorical_columns,dummy_na=True)
df_new=pd.concat([df1,df["SalePrice"]], axis=1)

# %%
df1
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            6       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %% [markdown]
# # preparing the data for modeling

# %%
# spliting the data into dependent and indepent variable
X=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=scaler.fit_transform(X)
# scaling the data

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(300)
X_pca=pca.fit_transform(X)

# %%
# pca.explained_variance_ratio_
X_pca.shape
# Out:
# (1460, 300)

# %% [markdown]
# # modeling

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.svm import SVR
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
svm_classifier=SVR(kernel="rbf", )
random_regressor=RandomForestRegressor(n_estimators=200)
logistic_regression=LogisticRegression()

# %%
num_kfold=5
kf=KFold(n_splits=num_kfold,shuffle=True,random_state=32)

# %%
cross_val_result=cross_val_score(random_regressor, X_pca,y ,cv=kf,scoring='r2')

print("Accuracy:",cross_val_result)
print("Mean Accuracy:",np.mean(cross_val_result))
# Out:
# Accuracy: [0.87104645 0.8979038  0.87433369 0.86156236 0.83803251]
# Mean Accuracy: 0.8685757614776852

# %% [markdown]
# # preparing the test data

# %%
import pandas as pd

# %%
df_test=pd.read_csv("~/Desktop/test.csv")

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
TEST= df_test["Id"].copy()

# %%
df_test.drop(["Id"], axis=1, inplace=True)

# %%
df_test.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
# Street             0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 79, dtype: int64

# %%
df_test.fillna(df_test.mean(),inplace=True)
# removing all the nan values and replacing it wih the mean value

# %%
Test_numerical_columns = [column for column in df_test.columns if df_test[column].dtype==int]

# %%
for column in Test_numerical_columns:
    outlier_detection(column, df)
# removing all the outliers and replacing it with the mean value

# %%
Test_categorical_columns = [column for column in df.columns if df[column].dtype=="object"]

# %%
df_testnew=pd.get_dummies(data=df_test,columns= Test_categorical_columns,dummy_na=True)
# converting all categorical variables to dummy variables

# %%
df_testnew
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             20         80.0    11622            5            6       1961
# 1             20         81.0    14267            6            6       1958
# 2             60         74.0    13830            5            5       1997
# 3             60         78.0     9978            6            6       1998
# 4            120         43.0     5005            8            5       1992
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
df_testnew =scaler.fit_transform(df_testnew)
# scaling the data

# %%
df_testnew.shape
# Out:
# (1459, 313)

# %%
pca=PCA(300)
X_test=pca.fit_transform(df_testnew)
# feature transformation using PCA

# %%
random_forest=random_regressor.fit( X_pca,y)
# training the model using the train data, X and y that was prepared

# %%
y_pred=random_forest.predict(X_test)

# %%
y_pred
# Out:
# array([205819.555, 214238.37 , 125185.   , ..., 176135.   , 213733.885,
#        126394.96 ])

# %%
df_result=pd.DataFrame({"Id":np.array(TEST),"y_pred":y_pred})

# %%
df_result
# Out:
#         Id      y_pred
# 0     1461  205819.555
# 1     1462  214238.370
# 2     1463  125185.000
# 3     1464  127786.315
# 4     1465  127225.325
# ...    ...         ...
# 1454  2915  271596.620
# 1455  2916  218360.650
# 1456  2917  176135.000
# 1457  2918  213733.885
# 1458  2919  126394.960
#
# [1459 rows x 2 columns]

# %%
import sys

sys. version
# Out:
# '3.7.6 (default, Jan  8 2020, 19:59:22) \n[GCC 7.3.0]'
