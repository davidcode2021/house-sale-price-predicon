# %%
import pandas as pd 
import numpy as np
import math

# %%
df=pd.read_csv("~/Downloads/train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Understanding the data

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.isna().sum()
# checking the number of missed values
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# # Droping features with high number of nan values

# %%
# Out:
# Alley
# PoolQC
# Fence
# MiscFeature

# %%
# df.drop(["Alley","FireplaceQu","PoolQC","Fence","MiscFeature"], axis=1, inplace=True)

# %%
mean=df.mean()
df.fillna(mean,inplace=True)

# %%
df["BsmtHalfBath"].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# # checking for outliers and replacing them with mean value of the features

# %%
numerical_columns = [column for column in df.columns if df[column].dtype==int and len(df[column].unique()<11)]
numerical_columns=numerical_columns[:-1].copy()

# %%
def outlier_detection(column, df):
    outlier=[]
    for x in  df[column]:
        z=np.divide(x-np.mean(df[column]),np.std(df[column]))
        if z > 3:
            outlier.append(x)
            df[column].replace(x,math.ceil(np.mean(df[column])),inplace=True)
    print(column, outlier)     
    

for column in numerical_columns:
    outlier_detection(column, df)
# Out:
# Id []
# MSSubClass []
# LotArea [21000, 21453, 31770, 22950, 25419, 20431, 22420, 21750, 21872, 21780, 25095, 20896, 21535, 26178, 21695, 21384, 21286, 21750, 20781, 20544, 19690]
# OverallQual []
# OverallCond []
# YearBuilt []
# YearRemodAdd []
# BsmtFinSF1 [1810, 1767, 1721]
# BsmtFinSF2 [486, 491, 506, 362, 169, 181, 215, 208, 441, 184, 279, 306, 180, 228, 175, 264, 147, 232, 380, 294, 258, 121, 180, 344, 210, 311, 165, 279, 180, 174, 139, 202, 123, 219, 147, 182, 132, 336, 287, 180, 180, 119, 182, 117, 239, 127, 128, 377, 345, 324, 93, 294, 149, 193, 117, 273, 64, 230, 106, 240, 287, 177, 108, 211, 168, 96, 144, 81, 68, 173, 105, 110, 163]
# BsmtUnfSF [1869, 1836]
# TotalBsmtSF [2223]
# 1stFlrSF [2207, 2223, 2259, 2234, 2217, 2196]
# 2ndFlrSF []
# LowQualFinSF [6, 6, 6, 5, 5, 5, 5, 6, 53, 3, 3, 2, 2, 2, 1, 1, 1, 1]
# GrLivArea [2945, 2978, 2872, 2898, 2868, 2872]
# BsmtFullBath []
# ...

# %%
# df["KitchenAbvGr"].unique()
# Out:
# array([1, 2, 0])

# %%
df.isna().sum() 
# confirming all the outliers are gone
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %% [markdown]
# # converting categorical features to dummy variables

# %%
categorical_columns = [column for column in df.columns if df[column].dtype=="object"]
categorical_columns
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df_new=pd.get_dummies(data=df,columns= categorical_columns,dummy_na=True)

# %%
df_new
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0   8450.0            7            5
# 1        2          20         80.0   9600.0            6            8
# 2        3          60         68.0  11250.0            7            5
# 3        4          70         60.0   9550.0            7            5
# 4        5          60         84.0  14260.0            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0   7917.0            6            5
# 1456  1457          20         85.0  13175.0            6            6
# 1457  1458          70         66.0   9042.0            7            6
# 1458  1459          20         68.0   9717.0            5            6
# 1459  1460          20         75.0   9937.0            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_Oth  \
# ...

# %% [markdown]
# # preparing the data for modeling

# %%
# spliting the data into dependent and indepent variable
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=scaler.fit_transform(X)
# scaling the data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-61aa9a5e1a09> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler=StandardScaler()
# ----> 3 X=scaler.fit_transform(X)
#       4 # scaling the data
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(70)
X_pca=pca.fit_transform(X)

# %%
pca.explained_variance_ratio_
